# %%
import os
import pathlib
import pandas as pd
import numpy as np
import sys
sys.path.append(str(pathlib.Path(os.getcwd()).parent))

# %%
from run.metadata_setup.check_data_exist import check_data_exist

# %%
# print all outputs.
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
project_id='lotte_mart' # lotte_mart, hdc
start_time="2024-03-23 00:00:00+0900"  # start_time of data check period (whether exist)
end_time="2024-03-23 23:59:00+0900" # end_time of data check period (whether exist)

update_metadata=False # if True update data/{project_id}/{sheet_name}.csv directly. Recommend to set False and copy-paste manually.

check_data_exist(project_id,start_time,end_time,update_metadata=False)
# Out:
# skip CT1 냉각수 공급온도AI-800
# skip CT1 냉각수 환수온도AI-801
# skip CT1 냉수 공급온도AI-802
# skip CT1 냉수 환수온도AI-803
# skip CT2-1 냉각수 공급온도AI-804
# skip CT2-1 냉각수 환수온도AI-805
# skip CT2-1 냉수 공급온도AI-806
# skip CT2-1 냉수 환수온도AI-807
# skip CT2-2 냉각수 공급온도AI-900
# skip CT2-2 냉각수 환수온도AI-901
# skip CT2-2 냉수 공급온도AI-902
# skip CT2-2 냉수 환수온도AI-903
# !!!!!!!!!!!!!!!!!!헤더 공급온도AI-904 exist!!!!!!!!!!!!!!!!!!!!
# skip 헤더 환수온도AI-905
# skip 급탕탱크온도    AI-906
# skip 냉온수기 물용 차압감지기AI-1100
# skip 지하저수조 수위AI-1101
# skip 보일러 증기헤어 압력AI-1102
# !!!!!!!!!!!!!!!!!!외기온도AI-1103 exist!!!!!!!!!!!!!!!!!!!!
# !!!!!!!!!!!!!!!!!!외기습도AI-1104 exist!!!!!!!!!!!!!!!!!!!!
# skip 냉동냉장창고 밸브(X)AO-300
# skip 급탕밸브(X)AO-301
# skip 열교환기 밸브(X)AO-302
# skip 급탕탱크설정온도AO-1601
# skip 열교환기 설정온도AO-1602
# skip 쇼케이스 설정온도AO-1603
# skip 냉각탑_쇼케이스 정지온도AO-1604
# skip 냉각탑_쇼케이스 기동온도AO-1605
# skip CT1 정지온도AO-1608
# skip CT1 기동온도AO-1609
# skip CT2 정동온도AO-1610
# skip CT2 기동온도AO-1611
# skip CT3 정동온도AO-1612
# skip CT3 기동온도AO-1613
# skip 냉각탑-1 #1 STABI-400
# ...
