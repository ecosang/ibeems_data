# %%
import os
import pathlib
import pandas as pd
import numpy as np
import sys
sys.path.append(str(pathlib.Path(os.getcwd()).parent))

# %%
from run.raw_data_query import raw_data_query

# %%
help(raw_data_query)
# Out:
# Help on function check_data_exist in module run.metadata_setup.check_data_exist:
#
# check_data_exist(project_id, start_time, end_time, update_metadata=False)
#     Check the data existance for a given project.
#     Description:
#         - This function checks the data existance for the given project and time period.
#         - The data existance is checked based on the point list and the raw data.
#         - The result is saved as a csv file in the data/project_id folder.
#
#
#     Args:
#         project_id (str): The ID of the project. #'lotte_mart' or 'hdc'
#         start_time (str): The start time in local or UTC timezone, formatted as %Y-%m-%d %H:%M:%S%z (e.g., '2024-03-07 00:00:00+0900' or '2024-03-07 00:00:00+0000')
#         end_time (str): The end time in local or UTC timezone, formatted as %Y-%m-%d %H:%M:%S%z (e.g., '2024-03-07 00:00:00+0900' or '2024-03-07 00:00:00+0000')
#         update_metadata (bool, optional): Whether to update the metadata. Defaults to False.
# ...

# %%
project_id="lotte_mart"

start_time='2024-03-22 00:00:00+0900' # start_time of data check period (if exist)
end_time='2024-03-23 00:00:00+0900' # end_time of data check period (if exist)

save_data=True # whether to save the data. If True, the data is saved in the save_dir.
save_dir=None # where to save the data. If None, the default directory is used.

# only quries (required==True) and (available=True) of data/{project_id}/{sheet_name}.csv
raw_df=raw_data_query(project_id, start_time, end_time, save_dir=save_dir,save_data=save_data)
# Out:
# default save_dir is download/rawdata/hdc
# data is stored in download/rawdata/hdc/raw_data_2024-03-22_2024-03-23.csv

# %%
raw_df
# Out:
#                timestamp_local  check_sf_status_ahu11  check_sf_status1_ahu11  \
# 0    2024-03-22 00:00:00+09:00                    0.0                     0.0
# 1    2024-03-22 00:00:30+09:00                    0.0                     0.0
# 2    2024-03-22 00:01:00+09:00                    0.0                     0.0
# 3    2024-03-22 00:01:30+09:00                    0.0                     0.0
# 4    2024-03-22 00:02:00+09:00                    0.0                     0.0
# ...                        ...                    ...                     ...
# 2876 2024-03-22 23:58:00+09:00                    0.0                     0.0
# 2877 2024-03-22 23:58:30+09:00                    0.0                     0.0
# 2878 2024-03-22 23:59:00+09:00                    0.0                     0.0
# 2879 2024-03-22 23:59:30+09:00                    0.0                     0.0
# 2880 2024-03-23 00:00:00+09:00                    0.0                     0.0
#
# ...
