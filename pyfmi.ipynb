# %%
import pyfmi
fmi_path="/home/srg-dell/ibeems_hybridsim/modelica_latest/Mo_cal_flex_updated_IO/Mo_0cal_0flex_0updated_0IO_iparkmall_0V9_0using_0AHUmodel_0array_0openloop_0SRP_0CO2_0gaschiller_0ihc.fmu"

# %%
fmu=pyfmi.load_fmu(fmi_path)

# %%
list(fmu.get_input_list())
# Out:
# ['in_mo_cvalve_position_frac01_ahu[1]',
#  'in_mo_cvalve_position_frac01_ahu[2]',
#  'in_mo_cvalve_position_frac01_ahu[3]',
#  'in_mo_cvalve_position_frac01_ahu[4]',
#  'in_mo_cvalve_position_frac01_ahu[5]',
#  'in_mo_cvalve_position_frac01_ahu[6]',
#  'in_mo_cvalve_position_frac01_ahu[7]',
#  'in_mo_cvalve_position_frac01_ahu[8]',
#  'in_mo_cvalve_position_frac01_ahu[9]',
#  'in_mo_cvalve_position_frac01_ahu[10]',
#  'in_mo_cvalve_position_frac01_ahu[11]',
#  'in_mo_hvalve_position_frac01_ahu[1]',
#  'in_mo_hvalve_position_frac01_ahu[2]',
#  'in_mo_hvalve_position_frac01_ahu[3]',
#  'in_mo_hvalve_position_frac01_ahu[4]',
#  'in_mo_hvalve_position_frac01_ahu[5]',
#  'in_mo_hvalve_position_frac01_ahu[6]',
#  'in_mo_hvalve_position_frac01_ahu[7]',
#  'in_mo_hvalve_position_frac01_ahu[8]',
#  'in_mo_hvalve_position_frac01_ahu[9]',
#  'in_mo_hvalve_position_frac01_ahu[10]',
#  'in_mo_hvalve_position_frac01_ahu[11]',
#  'in_mo_oadamper_position_frac01_ahu[1]',
# ...

# %%
fmu.initialize()

# %%
list(fmu.get_output_list())
# Out:
# ['out_mo_sa_temp_c_ahu[1]',
#  'out_mo_sa_temp_c_ahu[2]',
#  'out_mo_sa_temp_c_ahu[3]',
#  'out_mo_sa_temp_c_ahu[4]',
#  'out_mo_sa_temp_c_ahu[5]',
#  'out_mo_sa_temp_c_ahu[6]',
#  'out_mo_sa_temp_c_ahu[7]',
#  'out_mo_sa_temp_c_ahu[8]',
#  'out_mo_sa_temp_c_ahu[9]',
#  'out_mo_sa_temp_c_ahu[10]',
#  'out_mo_sa_temp_c_ahu[11]',
#  'out_mo_cc_load_kw_ahu[1]',
#  'out_mo_cc_load_kw_ahu[2]',
#  'out_mo_cc_load_kw_ahu[3]',
#  'out_mo_cc_load_kw_ahu[4]',
#  'out_mo_cc_load_kw_ahu[5]',
#  'out_mo_cc_load_kw_ahu[6]',
#  'out_mo_cc_load_kw_ahu[7]',
#  'out_mo_cc_load_kw_ahu[8]',
#  'out_mo_cc_load_kw_ahu[9]',
#  'out_mo_cc_load_kw_ahu[10]',
#  'out_mo_cc_load_kw_ahu[11]',
#  'out_mo_za_load_kw_ahu[1]',
#  'out_mo_za_load_kw_ahu[2]',
#  'out_mo_za_load_kw_ahu[3]',
#  'out_mo_za_load_kw_ahu[4]',
#  'out_mo_za_load_kw_ahu[5]',
#  'out_mo_za_load_kw_ahu[6]',
#  'out_mo_za_load_kw_ahu[7]',
#  'out_mo_za_load_kw_ahu[8]',
#  'out_mo_za_load_kw_ahu[9]',
#  'out_mo_za_load_kw_ahu[10]',
# ...
